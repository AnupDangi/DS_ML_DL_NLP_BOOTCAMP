# %%
pip list
# Out:
# Package                   Version
# ------------------------- -----------
# altair                    5.5.0
# appnope                   0.1.4
# asttokens                 3.0.1
# attrs                     25.4.0
# beautifulsoup4            4.14.2
# blinker                   1.9.0
# bs4                       0.0.2
# cachetools                6.2.2
# certifi                   2025.11.12
# charset-normalizer        3.4.4
# click                     8.1.8
# comm                      0.2.3
# contourpy                 1.3.0
# cycler                    0.12.1
# debugpy                   1.8.17
# decorator                 5.2.1
# exceptiongroup            1.3.1
# executing                 2.2.1
# Flask                     3.1.2
# fonttools                 4.60.1
# gitdb                     4.0.12
# GitPython                 3.1.45
# idna                      3.11
# importlib_metadata        8.7.0
# importlib_resources       6.5.2
# ipykernel                 6.31.0
# ipython                   8.18.1
# itsdangerous              2.2.0
# jedi                      0.19.2
# Jinja2                    3.1.6
# joblib                    1.5.2
# jsonschema                4.25.1
# jsonschema-specifications 2025.9.1
# jupyter_client            8.6.3
# jupyter_core              5.8.1
# kiwisolver                1.4.7
# kneed                     0.8.5
# MarkupSafe                3.0.3
# matplotlib                3.9.4
# matplotlib-inline         0.2.1
# narwhals                  2.12.0
# nest-asyncio              1.6.0
# numpy                     2.0.2
# packaging                 25.0
# pandas                    2.3.3
# parso                     0.8.5
# pexpect                   4.9.0
# pillow                    11.3.0
# pip                       25.3
# platformdirs              4.4.0
# plotly                    6.5.0
# prompt_toolkit            3.0.52
# protobuf                  6.33.1
# psutil                    7.1.3
# ptyprocess                0.7.0
# pure_eval                 0.2.3
# pyarrow                   21.0.0
# pydeck                    0.9.1
# Pygments                  2.19.2
# pyparsing                 3.2.5
# python-dateutil           2.9.0.post0
# pytz                      2025.2
# pyzmq                     27.1.0
# referencing               0.36.2
# requests                  2.32.5
# rpds-py                   0.27.1
# scikit-learn              1.6.1
# scipy                     1.13.1
# seaborn                   0.13.2
# setuptools                58.0.4
# six                       1.17.0
# smmap                     5.0.2
# soupsieve                 2.8
# stack-data                0.6.3
# streamlit                 1.50.0
# tenacity                  9.1.2
# threadpoolctl             3.6.0
# toml                      0.10.2
# tornado                   6.5.2
# traitlets                 5.14.3
# typing_extensions         4.15.0
# tzdata                    2025.2
# urllib3                   2.5.0
# wcwidth                   0.2.14
# Werkzeug                  3.1.3
# wheel                     0.45.1
# zipp                      3.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
corpus=""" 
    Hello Welcome,to krish Naik's NLP tutorials.
    Please do watch the entire course !to become expert in NLP.
"""

# %%
print(corpus)
# Out:
#
#     Hello Welcome,to krish Naik's NLP tutorials.
#     Please do watch the entire course !to become expert in NLP.

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /Users/anupdangi/Desktop/AnupAI/Research/DS_ML_DL_NLP_BOOTCAMP/venv/lib/python3.9/site-packages (3.9.2)
# Requirement already satisfied: click in /Users/anupdangi/Desktop/AnupAI/Research/DS_ML_DL_NLP_BOOTCAMP/venv/lib/python3.9/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /Users/anupdangi/Desktop/AnupAI/Research/DS_ML_DL_NLP_BOOTCAMP/venv/lib/python3.9/site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/anupdangi/Desktop/AnupAI/Research/DS_ML_DL_NLP_BOOTCAMP/venv/lib/python3.9/site-packages (from nltk) (2026.1.15)
# Requirement already satisfied: tqdm in /Users/anupdangi/Desktop/AnupAI/Research/DS_ML_DL_NLP_BOOTCAMP/venv/lib/python3.9/site-packages (from nltk) (4.67.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
## Tokenization 
## Sentence --> paragraphs

from nltk.tokenize import sent_tokenize 
import nltk

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/anupdangi/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
sent_tokenize(corpus)
# Out:
# [" \n    Hello Welcome,to krish Naik's NLP tutorials.",
#  'Please do watch the entire course !to become expert in NLP.']

# %%
documents=sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
#
#     Hello Welcome,to krish Naik's NLP tutorials.
# Please do watch the entire course !to become expert in NLP.

# %%
## Tokenization
## Paragraph => words 
## sentence => words

from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'krish', 'Naik', "'s", 'NLP', 'tutorials', '.']
# ['Please', 'do', 'watch', 'the', 'entire', 'course', '!', 'to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'krish',
#  'Naik',
#  "'",
#  's',
#  'NLP',
#  'tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
treetokenizer=TreebankWordTokenizer()

# %%
treetokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'tutorials.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
