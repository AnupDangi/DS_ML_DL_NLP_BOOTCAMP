# %% [markdown]
# IN natural language processing (NLP), word embeddings is a term used for the representation of word for text analysis, typically in the form of a real-valued
# vector that encodes the meaning  of the word such that the words that are closer in the vector space are expected to be similar in meaning.
