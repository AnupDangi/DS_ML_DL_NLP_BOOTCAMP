# %%
import gensim

# %%
pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (8.6 kB)
# Requirement already satisfied: numpy>=1.18.5 in /Users/anupdangi/Desktop/AnupAI/Research/DS_ML_DL_NLP_BOOTCAMP/venv/lib/python3.9/site-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /Users/anupdangi/Desktop/AnupAI/Research/DS_ML_DL_NLP_BOOTCAMP/venv/lib/python3.9/site-packages (from gensim) (1.13.1)
# Collecting smart_open>=1.8.1 (from gensim)
#   Downloading smart_open-7.5.0-py3-none-any.whl.metadata (24 kB)
# Collecting wrapt (from smart_open>=1.8.1->gensim)
#   Downloading wrapt-2.1.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Downloading gensim-4.4.0-cp39-cp39-macosx_11_0_arm64.whl (24.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.4/24.4 MB 1.6 MB/s  0:00:15 eta 0:00:010:01:03m
# Downloading smart_open-7.5.0-py3-none-any.whl (63 kB)
# Downloading wrapt-2.1.1-cp39-cp39-macosx_11_0_arm64.whl (61 kB)
# Installing collected packages: wrapt, smart_open, gensim
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [gensim]━━━━━━━━━━━ 2/3 [gensim]
# Successfully installed gensim-4.4.0 smart_open-7.5.0 wrapt-2.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from gensim.models import Word2Vec, KeyedVectors

# %%
import gensim.downloader as api

# %%
wv=api.load('word2vec-google-news-300')
# Out:
# [==------------------------------------------------] 5.6% 93.0/1662.8MB downloaded
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 wv=api.load('word2vec-google-news-300')
#
# File ~/Desktop/AnupAI/Research/DS_ML_DL_NLP_BOOTCAMP/venv/lib/python3.9/site-packages/gensim/downloader.py:496, in load(name, return_path)
#     494 path = os.path.join(folder_dir, file_name)
#     495 if not os.path.exists(folder_dir):
# --> 496     _download(name)
#     498 if return_path:
#     499     return path
#
# File ~/Desktop/AnupAI/Research/DS_ML_DL_NLP_BOOTCAMP/venv/lib/python3.9/site-packages/gensim/downloader.py:396, in _download(name)
#     394 fname = "{fname}.gz".format(fname=name)
#     395 dst_path = os.path.join(tmp_dir, fname)
# --> 396 urllib.urlretrieve(url_data, dst_path, reporthook=_progress)
#     397 if _calculate_md5_checksum(dst_path) == _get_checksum(name):
#     398     sys.stdout.write("\n")
#
# File ~/Desktop/AnupAI/Research/DS_ML_DL_NLP_BOOTCAMP/venv/lib/python3.9/urllib/request.py:268, in urlretrieve(url, filename, reporthook, data)
#     265     reporthook(blocknum, bs, size)
#     267 while True:
# --> 268     block = fp.read(bs)
#     269     if not block:
#     270         break
#
# File ~/Desktop/AnupAI/Research/DS_ML_DL_NLP_BOOTCAMP/venv/lib/python3.9/http/client.py:463, in HTTPResponse.read(self, amt)
#     460 if amt is not None:
#     461     # Amount is given, implement using readinto
#     462     b = bytearray(amt)
# --> 463     n = self.readinto(b)
#     464     return memoryview(b)[:n].tobytes()
#     465 else:
#     466     # Amount is not given (unbounded read) so we must check self.length
#     467     # and self.chunked
#
# File ~/Desktop/AnupAI/Research/DS_ML_DL_NLP_BOOTCAMP/venv/lib/python3.9/http/client.py:507, in HTTPResponse.readinto(self, b)
#     502         b = memoryview(b)[0:self.length]
#     504 # we do not use _safe_read() here because this may be a .will_close
#     505 # connection, and the user is reading more bytes than will be provided
#     506 # (for example, reading in 1k chunks)
# --> 507 n = self.fp.readinto(b)
#     508 if not n and b:
#     509     # Ideally, we would raise IncompleteRead if the content-length
#     510     # wasn't satisfied, but it might break compatibility.
#     511     self._close_conn()
#
# File ~/Desktop/AnupAI/Research/DS_ML_DL_NLP_BOOTCAMP/venv/lib/python3.9/socket.py:716, in SocketIO.readinto(self, b)
#     714 while True:
#     715     try:
# --> 716         return self._sock.recv_into(b)
#     717     except timeout:
#     718         self._timeout_occurred = True
#
# File ~/Desktop/AnupAI/Research/DS_ML_DL_NLP_BOOTCAMP/venv/lib/python3.9/ssl.py:1277, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1273     if flags != 0:
#    1274         raise ValueError(
#    1275           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1276           self.__class__)
# -> 1277     return self.read(nbytes, buffer)
#    1278 else:
#    1279     return super().recv_into(buffer, nbytes, flags)
#
# File ~/Desktop/AnupAI/Research/DS_ML_DL_NLP_BOOTCAMP/venv/lib/python3.9/ssl.py:1135, in SSLSocket.read(self, len, buffer)
#    1133 try:
#    1134     if buffer is not None:
# -> 1135         return self._sslobj.read(len, buffer)
#    1136     else:
#    1137         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
vec_king=wv['king']

# %%
vec_king

# %%
vec_king.shape

# %%
wv.most_similar('cricket')

# %%
wv.most_similar('happy')

# %%
wv.similarity('hockey','sports')

# %%
vec=wv['king'] -wv['man']+wv['woman']

# %%
vec

# %%
wv.most_similar([vec])
